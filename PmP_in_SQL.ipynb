# %% [markdown]
# ### Connect to the database, PmP, on the MySQL server running on localhost

# %%
#import all the required modules
import pymysql
import pandas as pd
import warnings
import mysql.connector

# %%
#connect to PmP database using pymysql.connect
conn = pymysql.connect(host="localhost",user="root",password="",database="PmP")

# %% [markdown]
# ### Explore the different tables and their columns

# %% [markdown]
# #### Table 1: Uniprot_to_Reactome
# I sourced this table from Reactome, a manually-curated, reliable knowledgebase of biological pathways. This table lists all proteins and the pathways that they belong in.

# %%
pd.read_sql_query("SELECT * FROM Uniprot_to_Reactome limit 3", conn)
# Out:
#    Uniprot_ID     Pathway_ID  \
# 0  A0A075B6P5   R-HSA-109582
# 1  A0A075B6P5  R-HSA-1280218
# 2  A0A075B6P5  R-HSA-1280218
#
#                                         Pathway_Link            Pathway_Name  \
# 0  https://reactome.org/PathwayBrowser/#/R-HSA-10...              Hemostasis
# 1  https://reactome.org/PathwayBrowser/#/R-HSA-12...  Adaptive Immune System
# 2  https://reactome.org/PathwayBrowser/#/R-HSA-12...  Adaptive Immune System
#
#   Mis_Code       Species
# 0      TAS  Homo sapiens
# 1      TAS  Homo sapiens
# 2      IEA  Homo sapiens

# %% [markdown]
# ##### Removing duplicates of Uniprot_ID-Pathway pairs
# There are some duplicates of Uniprot_ID-Pathway in the Uniprot_to_Reactome table due to different evidence codes (column Mis_Code) that is not of interest for this project, so I wrote a query to create a new table to remove these duplicates.

# %%
pd.read_sql_query("""CREATE TABLE Uniprot_to_Reactome_edited AS
                   SELECT DISTINCT Uniprot_ID, Pathway_ID, Pathway_Link, Pathway_Name FROM Uniprot_to_Reactome""", conn)

# %% [markdown]
# You can now see that the duplicate for the A0A075B6P5-R-HSA-1280218 pair has been removed in the new table, Uniprot_to_Reactome_edited.

# %%
pd.read_sql_query("SELECT * FROM Uniprot_to_Reactome_edited limit 3", conn)
# Out:
#    Uniprot_ID     Pathway_ID  \
# 0  A0A075B6P5   R-HSA-109582
# 1  A0A075B6P5  R-HSA-1280218
# 2  A0A075B6P5  R-HSA-1643685
#
#                                         Pathway_Link            Pathway_Name
# 0  https://reactome.org/PathwayBrowser/#/R-HSA-10...              Hemostasis
# 1  https://reactome.org/PathwayBrowser/#/R-HSA-12...  Adaptive Immune System
# 2  https://reactome.org/PathwayBrowser/#/R-HSA-16...                 Disease

# %% [markdown]
# #### Table 2: Chemical_Tools
# This table is a table of expert-reviewed chemical tools, compounds used in biochemical/cellular assays to study protein function. This table lists the chemical tools and the protein(s) they target.

# %%
pd.read_sql_query("SELECT * FROM Chemical_Tools limit 3", conn)
# Out:
#                                         Probe_SMILES  \
# 0  C[C@@]1(CCN1C(c1csc2ccccc12)=O)C(N(CCCC(O)=O)C...
# 1                C1CN(CCN1Cc1nc2ccccc2[nH]1)c1ccccn1
# 2            COc1cc(cc(c1OC)OC)Nc1ccnc2ccc(cc12)[Br]
#
#                                    Probe_Name Target_Name Uniprot_ID
# 0                 GPCR_GLPG-0974/CPP_GLPG0974       FFAR2     O15552
# 1                    GPCR_ABT-724/CPP_ABT-724        DRD4     P21917
# 2  KCGS_SGC-GAK-1/EUb_SGC-GAK-1/CPP_SGC-GAK-1         GAK     O14976

# %% [markdown]
# ### TASK 1: Show mapped results for a pathway of interest
# I wrote a query that would result in a table listing all proteins that pertain in the pathway of interest and chemical tools that target them (if any). Each row is unique for a protein-chemical_tool pair, and proteins that do not have chemical tools are also included in the list with the Probe_Name and Probe_SMILES values being NULL (i.e. 'None').
#
# The example pathway I used is the 'Interleukin-6 signaling' pathway (Pathway_ID: R-HSA-1059683).

# %%
pd.read_sql_query("""SELECT U.Pathway_ID, U.Pathway_Name, U.Uniprot_ID, C.Probe_Name, C.Probe_SMILES
                     FROM Uniprot_to_Reactome_edited U LEFT JOIN Chemical_Tools C 
                         ON(U.Uniprot_ID = C.Uniprot_ID) 
                     WHERE U.Pathway_ID='R-HSA-1059683'""", conn)
# Out:
#        Pathway_ID             Pathway_Name Uniprot_ID  \
# 0   R-HSA-1059683  Interleukin-6 signaling     O14543
# 1   R-HSA-1059683  Interleukin-6 signaling     O60674
# 2   R-HSA-1059683  Interleukin-6 signaling     O60674
# 3   R-HSA-1059683  Interleukin-6 signaling     O60674
# 4   R-HSA-1059683  Interleukin-6 signaling     O60674
# 5   R-HSA-1059683  Interleukin-6 signaling     O60674
# 6   R-HSA-1059683  Interleukin-6 signaling     O60674
# 7   R-HSA-1059683  Interleukin-6 signaling     O60674
# 8   R-HSA-1059683  Interleukin-6 signaling     O60674
# 9   R-HSA-1059683  Interleukin-6 signaling     O60674
# 10  R-HSA-1059683  Interleukin-6 signaling     O60674
# 11  R-HSA-1059683  Interleukin-6 signaling     O60674
# 12  R-HSA-1059683  Interleukin-6 signaling     O60674
# 13  R-HSA-1059683  Interleukin-6 signaling     O60674
# 14  R-HSA-1059683  Interleukin-6 signaling     P05231
# 15  R-HSA-1059683  Interleukin-6 signaling     P08887
# 16  R-HSA-1059683  Interleukin-6 signaling     P22681
# 17  R-HSA-1059683  Interleukin-6 signaling     P23458
# 18  R-HSA-1059683  Interleukin-6 signaling     P23458
# 19  R-HSA-1059683  Interleukin-6 signaling     P23458
# 20  R-HSA-1059683  Interleukin-6 signaling     P23458
# 21  R-HSA-1059683  Interleukin-6 signaling     P23458
# 22  R-HSA-1059683  Interleukin-6 signaling     P23458
# 23  R-HSA-1059683  Interleukin-6 signaling     P23458
# 24  R-HSA-1059683  Interleukin-6 signaling     P29597
# 25  R-HSA-1059683  Interleukin-6 signaling     P29597
# 26  R-HSA-1059683  Interleukin-6 signaling     P29597
# 27  R-HSA-1059683  Interleukin-6 signaling     P29597
# 28  R-HSA-1059683  Interleukin-6 signaling     P29597
# 29  R-HSA-1059683  Interleukin-6 signaling     P29597
# 30  R-HSA-1059683  Interleukin-6 signaling     P29597
# 31  R-HSA-1059683  Interleukin-6 signaling     P29597
# 32  R-HSA-1059683  Interleukin-6 signaling     P29597
# 33  R-HSA-1059683  Interleukin-6 signaling     P29597
# 34  R-HSA-1059683  Interleukin-6 signaling     P29597
# 35  R-HSA-1059683  Interleukin-6 signaling     P29597
# 36  R-HSA-1059683  Interleukin-6 signaling     P29597
# 37  R-HSA-1059683  Interleukin-6 signaling     P40189
# 38  R-HSA-1059683  Interleukin-6 signaling     P40763
# 39  R-HSA-1059683  Interleukin-6 signaling     P42224
# 40  R-HSA-1059683  Interleukin-6 signaling     Q06124
#
#                                           Probe_Name  \
# 0                                               None
# 1                                    CPP_Ruxolitinib
# 2                                     CPP_Gandotinib
# 3                                     CPP_BMS-911543
# 4                                         CPP_AZ-960
# 5                                    KCGS_BI01125081
# 6                                      KCGS_AKI-007a
# 7                                    KCGS_GSK1379761
# 8                                   KCGS_PFE-PKIS 34
# 9                                    KCGS_ESD0001927
# 10                                  EUb_Upadacitinib
# 11                                         EUb_XL019
# 12                     EUb_Filgotinib/CPP_Filgotinib
# 13  KCGS_PFE-PKIS 25/EUb_Tofacitinib/CPP_Tofacitinib
# 14                                              None
# 15                                              None
# 16                                              None
# 17                                   CPP_Ruxolitinib
# 18                                    KCGS_UNC-AP-49
# 19                                    KCGS_UNC-AP-37
# 20                                  EUb_Upadacitinib
# 21                     EUb_Filgotinib/CPP_Filgotinib
# 22  KCGS_PFE-PKIS 25/EUb_Tofacitinib/CPP_Tofacitinib
# 23                 KCGS_FM-381/EUb_FM-381/CPP_FM-381
# 24                               CPP_DEUCRAVACITINIB
# 25                                    KCGS_UNC-AP-49
# 26                                    KCGS_UNC-AP-32
# 27                                       KCGS_AH5015
# 28                                    KCGS_GW642138X
# 29                                   KCGS_ESD0001925
# 30                                   KCGS_ESD0001927
# 31                                    KCGS_UNC-AP-46
# 32                                    KCGS_UNC-AP-37
# 33                                   KCGS_UNC-NK-281
# 34                                  EUb_Upadacitinib
# 35                                KCGS_THZ1/CPP_THZ1
# 36  KCGS_PFE-PKIS 25/EUb_Tofacitinib/CPP_Tofacitinib
# 37                                              None
# 38                                         CPP_SD-36
# 39                                              None
# 40                                        CPP_TNO155
#
#                                          Probe_SMILES
# 0                                                None
# 1      C1CCC(C1)[C@@H](CC#N)n1cc(cn1)c1c2cc[nH]c2ncn1
# 2   Cc1c(Cc2ccc(cc2F)[Cl])n2c(c(CN3CCOCC3)cc(Nc3cc...
# 3   CCn1c(cc2c3c(c(Nc4cc(C)n(C)n4)nc12)ncn3C)C(N(C...
# 4   Cc1cc(Nc2c(cc(C#N)c(N[C@@H](C)c3ccc(cc3)F)n2)F...
# 5   C1COCCN1c1ccc(cn1)c1cc(c2cccnc2c1)OCc1c(cccn1)...
# 6     CCCNC(c1ccc(cc1)Nc1nc(c2c(cco2)n1)NCC(F)(F)F)=O
# 7   COc1cc(cc(c1OC)OC)Nc1nccc(n1)N1CCC(C1)NC(C1COc...
# 8    C[C@@H]1CCN(C[C@@H]1N(C)c1c2cc[nH]c2ncn1)C(CO)=O
# 9   CC[C@@H](CO)Nc1c(cnc(Nc2cccc(c2)NC(C(C)(C)C)=O...
# 10  CC[C@@H]1CN(C[C@@H]1c1cnc2cnc3c(cc[nH]3)n12)C(...
# 11  C1CC(C(Nc2ccc(cc2)c2ccnc(Nc3ccc(cc3)N3CCOCC3)n...
# 12  C1CC1C(Nc1nc2cccc(c3ccc(CN4CCS(CC4)(=O)=O)cc3)...
# 13  C[C@@H]1CCN(C[C@@H]1N(C)c1c2cc[nH]c2ncn1)C(CC#...
# 14                                               None
# 15                                               None
# 16                                               None
# 17     C1CCC(C1)[C@@H](CC#N)n1cc(cn1)c1c2cc[nH]c2ncn1
# 18  CC(C)(C)OC(NCCCNS(c1ccc(cc1)Nc1ncc2c(n1)N(C)c1...
# 19  CC(C)(C)OC(NCCCNS(c1ccc(cc1)Nc1ncc2c(n1)N(C)c1...
# 20  CC[C@@H]1CN(C[C@@H]1c1cnc2cnc3c(cc[nH]3)n12)C(...
# 21  C1CC1C(Nc1nc2cccc(c3ccc(CN4CCS(CC4)(=O)=O)cc3)...
# 22  C[C@@H]1CCN(C[C@@H]1N(C)c1c2cc[nH]c2ncn1)C(CC#...
# 23  CN(C)C(C(=Cc1ccc(c2nc3cnc4c(cc[nH]4)c3n2C2CCCC...
# 24  [2H]C([2H])([2H])NC(c1c(cc(NC(C2CC2)=O)nn1)Nc1...
# 25  CC(C)(C)OC(NCCCNS(c1ccc(cc1)Nc1ncc2c(n1)N(C)c1...
# 26  CC(C)(C)OC(NCCCNS(c1ccc(cc1)Nc1ncc2c(n1)N(C)c1...
# 27                      c1ccc(cc1)c1nc2c(N)ncnc2[nH]1
# 28                       COc1ccc(cc1)c1cc2c(N)ncnc2o1
# 29      CC[C@@H](CO)Nc1ccnc(Nc2cccc(c2)NC(C(C)C)=O)n1
# 30  CC[C@@H](CO)Nc1c(cnc(Nc2cccc(c2)NC(C(C)(C)C)=O...
# 31  CC(C)(C)OC(NCCCNS(c1ccc(cc1)Nc1ncc2c(Nc3ccsc3C...
# 32  CC(C)(C)OC(NCCCNS(c1ccc(cc1)Nc1ncc2c(n1)N(C)c1...
# 33   CN(C)CC(N1CCN(CC1)c1ccn2c(c(cn2)c2cccnc2OC)n1)=O
# 34  CC[C@@H]1CN(C[C@@H]1c1cnc2cnc3c(cc[nH]3)n12)C(...
# 35  CN(C)CC=CC(Nc1ccc(cc1)C(Nc1cccc(c1)Nc1ncc(c(c2...
# 36  C[C@@H]1CCN(C[C@@H]1N(C)c1c2cc[nH]c2ncn1)C(CC#...
# 37                                               None
# 38  C(CCC#Cc1cccc2C(N(Cc12)C1CCC(NC1=O)=O)=O)CCC(N...
# 39                                               None
# 40  C[C@H]1[C@H](C2(CCN(CC2)c2cnc(c(N)n2)Sc2ccnc(c...

# %% [markdown]
# ### TASK 2: Get the chemical coverage (i.e. percentage of proteins that have chemical tools) for a pathway of interest
#
# Perhaps one is interested in determining whether more efforts for chemical tool development is required for the pathway of interest. This can be gauged by determining how many, or what percent, of the proteins that belong in the pathway have chemical tools that target them.
#
# Here is the query I wrote to determine the chemical coverage of the 'Interleukin-6 signaling' pathway (Pathway_ID: R-HSA-1059683).

# %%
pd.read_sql_query("""
                  SELECT x.number / y.number as Chemical_Coverage
                  FROM
                  (
                  SELECT COUNT(*) as number
                  FROM Uniprot_to_Reactome_edited U LEFT JOIN Chemical_Tools C 
                      ON(U.Uniprot_ID = C.Uniprot_ID) 
                  WHERE U.Pathway_ID='R-HSA-1059683' and C.Probe_Name IS NULL
                  ) x
                  JOIN
                  (
                  SELECT COUNT(DISTINCT U.Uniprot_ID) as number
                  FROM Uniprot_to_Reactome_edited U LEFT JOIN Chemical_Tools C 
                      ON(U.Uniprot_ID = C.Uniprot_ID) 
                  WHERE U.Pathway_ID='R-HSA-1059683'
                  ) y
                  """, conn)
# Out:
#    Chemical_Coverage
# 0             0.5455
